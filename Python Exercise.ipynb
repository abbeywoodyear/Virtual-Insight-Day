# %% [markdown]
# # Virtual Insight Week 2021

# %% [markdown]
# ## Beginner Python Exercise

# %%
print("hello")
# Out:
# hello

# %%
a = 5
b = 3

print(5 + 3)
# Out:
# 8

# %%
a = 6
b = 2

def times_two_numbers():
    c = a * b
    return c

print(times_two_numbers())
# Out:
# 12

# %%
def times_two_input_numbers(a, b):
    c = a * b
    return c

print(times_two_input_numbers(4, 4))
# Out:
# 16

# %%
def times_two_scanned_numbers():
    a = int(input('Enter your first number: '))
    b = int(input('Enter your second number: '))
    c = a * b
    return c

print(times_two_scanned_numbers())
# Out:
# Enter your first number: 3
# Enter your second number: 10
# 30

# %%
def add_two_scanned_numbers():
    a = int(input('Enter your first number: '))
    b = int(input('Enter your second number: '))
    c = a + b
    return c

# Show variable assigned to function output

x = add_two_scanned_numbers()
y = 3
z = x + y
print(z)
# Out:
# Enter your first number: 5
# Enter your second number: 7
# 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-901802ef9f3a> in <module>
#       7 x = print(add_two_scanned_numbers())
#       8 y = 3
# ----> 9 z = x + y
#      10 print(z)
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %% [markdown]
# #### Show packages

# %%
from datetime import date

print(date.today())
# Out:
# 2021-03-30
